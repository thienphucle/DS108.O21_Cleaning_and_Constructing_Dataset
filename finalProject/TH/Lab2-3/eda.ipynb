# 7     3 tháng chính hãng  Intel Core i5 Coffee Lake - 8259U    16 GB
# 8   3.5 tháng chính hãng  Intel Core i5 Coffee Lake - 8259U    16 GB
# 9   4.5 tháng chính hãng  Intel Core i5 Coffee Lake - 8259U    16 GB
# 10     01 tháng tại TGDĐ  Intel Core i7 Tiger Lake - 1165G7    16 GB
# 11  5.5 tháng chính hãng  Intel Core i5 Coffee Lake - 8259U    16 GB
# 12    4 tháng chính hãng  Intel Core i5 Coffee Lake - 8259U    16 GB
# 13    5 tháng chính hãng  Intel Core i5 Coffee Lake - 8259U    16 GB
# 14    2 tháng chính hãng              Intel Celeron - N4020     8 GB
# 15      1 tháng tại TGDĐ              Intel Celeron - N4020     8 GB
# 16      1 tháng tại TGDĐ  Intel Core i7 Tiger Lake - 1165G7    16 GB
# 17  2.5 tháng chính hãng              Intel Celeron - N4020     8 GB
# 18  1.5 tháng chính hãng              Intel Celeron - N4020     8 GB
# 19      1 tháng tại TGDĐ              Intel Celeron - N4020     8 GB
#
#                  Ram_type                                         Hard_Drive  \
# 0                   DDR3L                                 128 GB SSD M2 PCIe
# 1   DDR4 (Onboard +1 khe)     Hỗ trợ khe cắm HDD SATA\n256 GB SSD M.2 SATA 3
# 2          DDR3 (Onboard)                               512 GB SSD NVMe PCIe
# 3          DDR4 (Onboard)                               256 GB SSD NVMe PCIe
# 4          DDR4 (Onboard)  512 GB SSD\nHỗ trợ khe cắm SSD M.2 SATA3 (nâng...
# 5          DDR4 (Onboard)                               256 GB SSD NVMe PCIe
# 6          DDR4 (Onboard)  512 GB SSD\nHỗ trợ khe cắm SSD M.2 SATA3 (nâng...
# 7          DDR4 (Onboard)  512 GB SSD\nHỗ trợ khe cắm SSD M.2 SATA3 (nâng...
# 8          DDR4 (Onboard)  512 GB SSD\nHỗ trợ khe cắm SSD M.2 SATA3 (nâng...
# 9          DDR4 (Onboard)  512 GB SSD\nHỗ trợ khe cắm SSD M.2 SATA3 (nâng...
# 10      LPDDR4X (Onboard)  512 GB SSD NVMe PCIe\nHỗ trợ thêm 1 khe cắm SS...
# 11         DDR4 (Onboard)  512 GB SSD\nHỗ trợ khe cắm SSD M.2 SATA3 (nâng...
# 12         DDR4 (Onboard)  512 GB SSD\nHỗ trợ khe cắm SSD M.2 SATA3 (nâng...
# 13         DDR4 (Onboard)  512 GB SSD\nHỗ trợ khe cắm SSD M.2 SATA3 (nâng...
# 14       LPDDR4 (Onboard)                                         256 GB SSD
# 15       LPDDR4 (Onboard)                                         256 GB SSD
# 16      LPDDR4X (Onboard)  512 GB SSD NVMe PCIe\nHỗ trợ thêm 1 khe cắm SS...
# 17       LPDDR4 (Onboard)                                         256 GB SSD
# 18       LPDDR4 (Onboard)                                         256 GB SSD
# 19       LPDDR4 (Onboard)                                         256 GB SSD
#
#        screen             resolution  \
# 0     12 inch       2K (2160 x 1440)
# 1   15.6 inch  Full HD (1920 x 1080)
# 2     14 inch  Full HD (1920 x 1080)
# 3     14 inch  Full HD (1920 x 1080)
# 4     14 inch       2.2K (2240x1400)
# 5     14 inch  Full HD (1920 x 1080)
# 6     14 inch       2.2K (2240x1400)
# 7     14 inch       2.2K (2240x1400)
# 8     14 inch       2.2K (2240x1400)
# 9     14 inch       2.2K (2240x1400)
# 10    16 inch    WQXGA (2560 x 1600)
# 11    14 inch       2.2K (2240x1400)
# 12    14 inch       2.2K (2240x1400)
# 13    14 inch       2.2K (2240x1400)
# 14  14.1 inch  Full HD (1920 x 1080)
# 15  14.1 inch  Full HD (1920 x 1080)
# 16    16 inch    WQXGA (2560 x 1600)
# 17  14.1 inch  Full HD (1920 x 1080)
# 18  14.1 inch  Full HD (1920 x 1080)
# 19  14.1 inch  Full HD (1920 x 1080)
#
#                                         graphics  \
# 0         Card tích hợp - Intel UHD Graphics 620
# 1         Card tích hợp - Intel UHD Graphics 620
# 2         Card tích hợp - Intel UHD Graphics 615
# 3         Card tích hợp - Intel UHD Graphics 620
# 4   Card tích hợp - Intel Iris Plus Graphics 655
# 5         Card tích hợp - Intel UHD Graphics 620
# 6   Card tích hợp - Intel Iris Plus Graphics 655
# 7   Card tích hợp - Intel Iris Plus Graphics 655
# 8   Card tích hợp - Intel Iris Plus Graphics 655
# 9   Card tích hợp - Intel Iris Plus Graphics 655
# 10        Card tích hợp - Intel Iris Xe Graphics
# 11  Card tích hợp - Intel Iris Plus Graphics 655
# 12  Card tích hợp - Intel Iris Plus Graphics 655
# 13  Card tích hợp - Intel Iris Plus Graphics 655
# 14        Card tích hợp - Intel UHD Graphics 600
# 15        Card tích hợp - Intel UHD Graphics 600
# 16        Card tích hợp - Intel Iris Xe Graphics
# 17        Card tích hợp - Intel UHD Graphics 600
# 18        Card tích hợp - Intel UHD Graphics 600
# 19        Card tích hợp - Intel UHD Graphics 600
#
#                                           size_weight  \
# 0   Dài Dài 292.9 mm - Rộng Rộng 201.8 mm - Dày Dà...
# 1   Dài Dài 359 mm - Rộng Rộng 243 mm - Dày Dày 16...
# 2   Dài Dài 317.9 mm - Rộng Rộng 191.5 - Dày Dày 9...
# 3   Dài 329 mm - Rộng 228 mm - Dày 14.9 mm - Nặng ...
# 4   Dài 310 mm - Rộng 229.5 mm - Dày 20.6 mm - Nặn...
# 5   Dài 329 mm - Rộng 228 mm - Dày 14.9 mm - Nặng ...
# 6   Dài 310 mm - Rộng 229.5 mm - Dày 20.6 mm - Nặn...
# 7   Dài 310 mm - Rộng 229.5 mm - Dày 20.6 mm - Nặn...
# 18         Li-ion, 38 Wh
# 19         Li-ion, 38 Wh

# %%
def chuyen_gia_tri_so(chuoi):
    # Xóa các ký tự không mong muốn khỏi chuỗi
    chuoi = chuoi.replace('.', '').replace('₫', '').strip()

    # Chuyển chuỗi thành giá trị số
    gia_tri_so = float(chuoi)

    return gia_tri_so

df['price_old'] = df['price_old'].apply(chuyen_gia_tri_so)
df['price_new'] = df['price_new'].apply(chuyen_gia_tri_so)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 df['price_old'] = df['price_old'].apply(chuyen_gia_tri_so)
# ----> 2 df['price_new'] = df['price_old'].apply(chuyen_gia_tri_so)
#
# File ~\PycharmProjects\pythonProject\venv\Lib\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# File ~\PycharmProjects\pythonProject\venv\Lib\site-packages\pandas\core\apply.py:1207, in SeriesApply.apply(self)
#    1204     return self.apply_compat()
#    1206 # self.func is Callable
# -> 1207 return self.apply_standard()
#
# File ~\PycharmProjects\pythonProject\venv\Lib\site-packages\pandas\core\apply.py:1287, in SeriesApply.apply_standard(self)
#    1281 # row-wise access
#    1282 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1283 # we need to give `na_action="ignore"` for categorical data.
#    1284 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1285 #  Categorical (GH51645).
#    1286 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1287 mapped = obj._map_values(
#    1288     mapper=curried, na_action=action, convert=self.convert_dtype
#    1289 )
#    1291 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1292     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1293     #  See also GH#25959 regarding EA support
#    1294     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\PycharmProjects\pythonProject\venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\PycharmProjects\pythonProject\venv\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2920, in pandas._libs.lib.map_infer()
#
# Cell In[10], line 3, in chuyen_gia_tri_so(chuoi)
#       1 def chuyen_gia_tri_so(chuoi):
#       2     # Xóa các ký tự không mong muốn khỏi chuỗi
# ----> 3     chuoi = chuoi.replace('.', '').replace('₫', '').strip()
#       5     # Chuyển chuỗi thành giá trị số
#       6     gia_tri_so = float(chuoi)
#
# AttributeError: 'float' object has no attribute 'replace'
